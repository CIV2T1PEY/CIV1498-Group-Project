# %%
#Setup Notebook
# Import 3rd party libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
# import CSV

SBA_Loan = pd.read_csv('SBAnational.csv', low_memory=False)

# %%
SBA_Loan.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  DisbursementGross  \
# 0  ...          N       Y         NaN         28-Feb-99        $60,000.00
# 1  ...          N       Y         NaN         31-May-97        $40,000.00
# 2  ...          N       N         NaN         31-Dec-97       $287,000.00
# 3  ...          N       Y         NaN         30-Jun-97        $35,000.00
# 4  ...          N       N         NaN         14-May-97       $229,000.00
#
#    BalanceGross  MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0        $0.00        P I F       $0.00    $60,000.00    $48,000.00
# 1        $0.00        P I F       $0.00    $40,000.00    $32,000.00
# 2        $0.00        P I F       $0.00   $287,000.00   $215,250.00
# 3        $0.00        P I F       $0.00    $35,000.00    $28,000.00
# 4        $0.00        P I F       $0.00   $229,000.00   $229,000.00
#
# [5 rows x 27 columns]

# %%
#Check shape and description

SBA_Loan.dtypes
# Out:
# LoanNr_ChkDgt          int64
# Name                  object
# City                  object
# State                 object
# Zip                    int64
# Bank                  object
# BankState             object
# NAICS                  int64
# ApprovalDate          object
# ApprovalFY            object
# Term                   int64
# NoEmp                  int64
# NewExist             float64
# CreateJob              int64
# RetainedJob            int64
# FranchiseCode          int64
# UrbanRural             int64
# RevLineCr             object
# LowDoc                object
# ChgOffDate            object
# DisbursementDate      object
# DisbursementGross     object
# BalanceGross          object
# MIS_Status            object
# ChgOffPrinGr          object
# GrAppv                object
# SBA_Appv              object
# dtype: object

# %%
SBA_Loan.isnull().sum()

#lets decide which columns to drop
#lots of NaNs for Bank and Bank state, disbursement date

SBA_Loan = SBA_Loan[SBA_Loan['State'].notna()]

# %%
SBA_Loan.isnull().sum()
# Out:
# LoanNr_ChkDgt             0
# Name                     14
# City                     30
# State                     0
# Zip                       0
# Bank                   1558
# BankState              1565
# NAICS                     0
# ApprovalDate              0
# ApprovalFY                0
# Term                      0
# NoEmp                     0
# NewExist                136
# CreateJob                 0
# RetainedJob               0
# FranchiseCode             0
# UrbanRural                0
# RevLineCr              4528
# LowDoc                 2582
# ChgOffDate           736454
# DisbursementDate       2367
# DisbursementGross         0
# BalanceGross              0
# MIS_Status             1996
# ChgOffPrinGr              0
# GrAppv                    0
# SBA_Appv                  0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

#stratify on state to create a working data_zet
test, working_data = train_test_split(SBA_Loan, test_size=0.05, random_state=0, stratify=SBA_Loan['State'])

# %%
working_data.shape
# Out:
# (44958, 27)

# %%
test.shape
# Out:
# (854192, 27)

# %%
working_data
# Out:
#         LoanNr_ChkDgt                            Name         City State  \
# 774010     8176773007             RAFAEL'S RESTAURANT     EDINBURG    TX
# 210377     2485365001                   JULIE L DAVIS  YORBA LINDA    CA
# 830534     8919103007               CHAPTER III, INC.        GOWEN    MI
# 340408     3374925005     Richard M. Adams D.P.M.P.A.     Granbury    TX
# 565809     5574173006            RMTS ASSOCIATES INC.     NEW YORK    NY
# ...               ...                             ...          ...   ...
# 356265     3481896000        KIDDIE KOLLEGE INSTITUTE       CAMDEN    DE
# 783211     8303661010         MACDUFFS RESTAURANT INC    JAMESTOWN    NY
# 880913     9570023008                SHADES OF SUMMER  ST. SHARLES    MO
# 414985     4010164010                       FINN CORP    KALAMAZOO    MI
# 138888     2014655009  Margaret Ely DBA Marge Ely Pho   New Market    MD
#
#           Zip                           Bank BankState   NAICS ApprovalDate  \
# 774010  78539   TEXAS ST. BANK A DIVISION OF        TX       0    16-Mar-95
# 210377  92886    WELLS FARGO BANK NATL ASSOC        SD  541211    30-May-07
# 830534  49326   THE HUNTINGTON NATIONAL BANK        MI  453220    11-Jan-96
# 340408  76048                 COMMUNITY BANK        TX  621391    10-Apr-09
# 565809  10013                 CITIBANK, N.A.        NY       0     9-Mar-93
# ...       ...                            ...       ...     ...          ...
# 356265  19934       WILMINGTON TRUST COMPANY        DE  624410    17-Oct-08
# 783211  14701  FIRST NIAGARA BANK NATL ASSOC        NY       0    20-Sep-79
# 880913  63366     BANK OF AMERICA NATL ASSOC        MO       0    24-Sep-96
# 414985  49008     BANK OF AMERICA NATL ASSOC        MI  722211    17-Oct-00
# 138888  21774  MANUFACTURERS & TRADERS TR CO        NY  541922    13-Sep-06
#
#        ApprovalFY  ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  \
# 774010       1995  ...          N       Y         NaN         30-Apr-95
# 210377       2007  ...          Y       N         NaN         30-Jun-07
# 830534       1996  ...          N       Y         NaN         30-Apr-96
# 340408       2009  ...          N       N         NaN         30-Apr-09
# 565809       1993  ...          N       N         NaN         14-Jun-93
# ...           ...  ...        ...     ...         ...               ...
# 356265       2009  ...          0       N         NaN         31-Oct-08
# 783211       1979  ...          N       N   17-Jul-95         11-Oct-79
# 880913       1996  ...          0       N         NaN         31-May-98
# 414985       2001  ...          0       N    3-Apr-06         30-Nov-00
# 138888       2006  ...          Y       N   14-Jun-13         30-Sep-06
#
#         DisbursementGross  BalanceGross  MIS_Status  ChgOffPrinGr  \
# 774010        $20,000.00         $0.00        P I F        $0.00
# 210377        $67,401.00         $0.00        P I F        $0.00
# 830534       $100,000.00         $0.00        P I F        $0.00
# 340408       $160,000.00         $0.00        P I F        $0.00
# 565809       $325,000.00         $0.00        P I F        $0.00
# ...                   ...           ...         ...           ...
# 356265        $25,000.00         $0.00        P I F        $0.00
# 783211        $61,000.00         $0.00       CHGOFF    $7,759.00
# 880913        $40,000.00         $0.00        P I F        $0.00
# 414985       $309,000.00         $0.00       CHGOFF  $119,385.00
# 138888        $65,590.00         $0.00       CHGOFF    $9,523.00
#
#               GrAppv      SBA_Appv
# 774010   $20,000.00    $17,400.00
# 210377   $30,000.00    $15,000.00
# 830534  $100,000.00    $80,000.00
# 340408  $160,000.00   $144,000.00
# 565809  $325,000.00   $276,250.00
# ...              ...           ...
# 356265   $25,000.00    $12,500.00
# 783211   $61,000.00    $54,900.00
# 880913   $40,000.00    $20,000.00
# 414985  $309,000.00   $231,750.00
# 138888   $25,000.00    $12,500.00
#
# [44958 rows x 27 columns]

# %%
#export mini df

working_data.to_csv('mini_SBA_data.csv',index=False)
